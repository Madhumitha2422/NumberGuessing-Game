# %%
from tkinter import *
from random import randint
root=Tk()
root.geometry("500x300")
root.title("Number Guessing Game")
root.configure(bg="hotpink3")


random_num=randint(1,100)


def guess():
    
   
    entry_val=int(num_entry.get())
    try:
        
        if entry_val>random_num:
           
                msg["text"]="Too High!!!"
               
        elif entry_val<random_num:
            
                msg["text"]="Too Low!!!"
               
        else:
            
            msg["text"]="CORRECT"

            
    except:
            msg["text"] ="Please enter a number"   

            

heading=Label(root,text="Number guessing game",font=("Helvetica",15,"bold") ,bg="hotpink3")
heading.pack()

lbl_intro=Label(root,text="Guess number between 1 to 100",bg="hotpink3")
lbl_intro.pack()

lbl_number=Label(root,text="Guess Number",bg="hotpink3")
lbl_number.pack()

num_entry=Entry(root,font=("lucida",30,"bold"),border=10,bg="steelblue",fg="white")
num_entry.pack()

cal_btn=Button(root,text="Guess",width=50,height=2,bg="black",font=("lucida",13,"bold"),fg="white",relief=RIDGE,command=guess)
cal_btn.pack(pady=10)

msg=Label(root,text="",font=("Helvetica",15,"bold"))
msg.pack()

root.mainloop()
